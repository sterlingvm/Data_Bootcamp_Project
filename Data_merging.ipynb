# %%
import pandas as pd

# %%
who_data = pd.read_csv("WHO-COVID-19-global-table-data.csv")

# %%
who_data.head(15)
# Out:
#                                      Name  WHO Region  \
# Global                                NaN   516476402
# United States of America         Americas    81178013
# India                     South-East Asia    43110586
# Brazil                           Americas    30574245
# France                             Europe    28172780
# Germany                            Europe    25503878
# The United Kingdom                 Europe    22144632
# Russian Federation                 Europe    18241329
# Republic of Korea         Western Pacific    17658794
# Italy                              Europe    16872618
# Turkey                             Europe    15046779
# Spain                              Europe    12058888
# Viet Nam                  Western Pacific    10681214
# Argentina                        Americas     9101319
# Japan                     Western Pacific     8172238
#
#                           Cases - cumulative total  \
# ...

# %%
who_data["Case_Fatality_Ratio"] = ((who_data["Deaths - cumulative total"]/who_data["Cases - cumulative total"])*100)

# %%
who_data.columns = ["WHO Region",
"Cases - cumulative total",
"Cases - cumulative total per 100000 population",
"Cases - newly reported in last 7 days",
"Cases - newly reported in last 7 days per 100000 population",
"Cases - newly reported in last 24 hours",
"Deaths - cumulative total",
"Deaths - cumulative total per 100000 population","Deaths - newly reported in last 7 days",
"Deaths - newly reported in last 7 days per 100000 population",
"Deaths - newly reported in last 24 hours",
"Delete_This",
"Case_Fatality_Ratio"]

who_data = who_data.drop(["Delete_This"], axis=1)

who_data.head()
# Out:
#                                WHO Region  Cases - cumulative total  \
# Global                                NaN                 516476402
# United States of America         Americas                  81178013
# India                     South-East Asia                  43110586
# Brazil                           Americas                  30574245
# France                             Europe                  28172780
#
#                           Cases - cumulative total per 100000 population  \
# Global                                                        6626.13032
# United States of America                                     24524.88300
# India                                                         3123.94600
# Brazil                                                       14383.85800
# France                                                       43316.50900
#
#                           Cases - newly reported in last 7 days  \
# ...

# %%
who_data.index.rename("Name", inplace=True)

who_data.reset_index(inplace=True)

who_data.head()
# Out:
#                        Name       WHO Region  Cases - cumulative total  \
# 0                    Global              NaN                 516476402
# 1  United States of America         Americas                  81178013
# 2                     India  South-East Asia                  43110586
# 3                    Brazil         Americas                  30574245
# 4                    France           Europe                  28172780
#
#    Cases - cumulative total per 100000 population  \
# 0                                      6626.13032
# 1                                     24524.88300
# 2                                      3123.94600
# 3                                     14383.85800
# 4                                     43316.50900
#
#    Cases - newly reported in last 7 days  \
# 0                                3557106
# 1                                 492020
# 2                                  22468
# 3                                 113248
# ...

# %%
who_data.to_csv("who_data.csv",index=False)
