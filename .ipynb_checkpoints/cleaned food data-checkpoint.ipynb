# %%
import pandas as pd

# %%
food_data = "food_data.csv"
food_df = pd.read_csv(food_data)

# %%
food_df.head()
# Out:
#                Country  Alcoholic Beverages  Animal fats  Animal Products  \
# 0          Afghanistan               0.0014       0.1973           9.4341
# 1              Albania               1.6719       0.1357          18.7684
# 2              Algeria               0.2711       0.0282           9.6334
# 3               Angola               5.8087       0.0560           4.9278
# 4  Antigua and Barbuda               3.5764       0.0087          16.6613
#
#    Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 0                      0.0                   24.8097  0.2099         0.0350
# 1                      0.0                    5.7817  0.5815         0.2126
# 2                      0.0                   13.6816  0.5277         0.2416
# 3                      0.0                    9.1085  0.0587         1.7707
# 4                      0.0                    5.9960  0.2274         4.1489
#
# ...

# %%
food_df.drop(["Animal fats","Aquatic Products, Other","Miscellaneous","Offals","Oilcrops","Pulses","Spices","Starchy Roots","Stimulants","Sugar Crops","Confirmed","Deaths","Recovered","Active","Population","Unit (all except Population)"], axis=1, inplace=True)
food_df
# Out:
#                                 Country  Alcoholic Beverages  Animal Products  \
# 0                           Afghanistan               0.0014           9.4341
# 1                               Albania               1.6719          18.7684
# 2                               Algeria               0.2711           9.6334
# 3                                Angola               5.8087           4.9278
# 4                   Antigua and Barbuda               3.5764          16.6613
# ..                                  ...                  ...              ...
# 165  Venezuela (Bolivarian Republic of)               2.5952          14.7565
# 166                             Vietnam               1.4591           8.5765
# 167                               Yemen               0.0364           5.7874
# 168                              Zambia               5.7360           6.0197
# 169                            Zimbabwe               4.0552           8.1489
#
# ...

# %%
food_df.rename(columns={'Country': 'COUNTRY'}, inplace=True)
food_df.head(10)
# Out:
#                COUNTRY  Alcoholic Beverages  Animal Products  \
# 0          Afghanistan               0.0014           9.4341
# 1              Albania               1.6719          18.7684
# 2              Algeria               0.2711           9.6334
# 3               Angola               5.8087           4.9278
# 4  Antigua and Barbuda               3.5764          16.6613
# 5            Argentina               4.2672          19.3454
# 6              Armenia               0.4014          13.5640
# 7            Australia               5.5436          21.4175
# 8              Austria               7.0215          19.5654
# 9           Azerbaijan               3.5969          11.6416
#
#    Cereals - Excluding Beer    Eggs  Fish, Seafood  Fruits - Excluding Wine  \
# 0                   24.8097  0.2099         0.0350                   5.3495
# 1                    5.7817  0.5815         0.2126                   6.7861
# ...

# %%
# replace "<2.5" values in Undernourished column with zeroes 
food_df.loc[food_df.Undernourished=="<2.5", 'Undernourished'] = 0
food_df.head(10)
# Out:
#                COUNTRY  Alcoholic Beverages  Animal Products  \
# 0          Afghanistan               0.0014           9.4341
# 1              Albania               1.6719          18.7684
# 2              Algeria               0.2711           9.6334
# 3               Angola               5.8087           4.9278
# 4  Antigua and Barbuda               3.5764          16.6613
# 5            Argentina               4.2672          19.3454
# 6              Armenia               0.4014          13.5640
# 7            Australia               5.5436          21.4175
# 8              Austria               7.0215          19.5654
# 9           Azerbaijan               3.5969          11.6416
#
#    Cereals - Excluding Beer    Eggs  Fish, Seafood  Fruits - Excluding Wine  \
# 0                   24.8097  0.2099         0.0350                   5.3495
# 1                    5.7817  0.5815         0.2126                   6.7861
# ...

# %%
# drop NA rows from food df
final_food_df = food_df.dropna()
final_food_df.head(20)
# Out:
#                    COUNTRY  Alcoholic Beverages  Animal Products  \
# 0              Afghanistan               0.0014           9.4341
# 1                  Albania               1.6719          18.7684
# 2                  Algeria               0.2711           9.6334
# 3                   Angola               5.8087           4.9278
# 5                Argentina               4.2672          19.3454
# 6                  Armenia               0.4014          13.5640
# 7                Australia               5.5436          21.4175
# 8                  Austria               7.0215          19.5654
# 9               Azerbaijan               3.5969          11.6416
# 11              Bangladesh               0.0031           5.1926
# 12                Barbados               3.5650          12.4976
# 13                 Belarus               3.7563          12.7089
# 14                 Belgium               5.3730          17.7279
# ...

# %%
final_food_df.to_csv("final_food_data.csv", index=False)
