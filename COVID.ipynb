# %%
import pandas as pd
import numpy as np

# %%
# load csv files
covid19_data = "covid_19_data.csv"
food_data = "food_data.csv"

# read files into DFs
covid_df = pd.read_csv(covid19_data, index_col=2)
food_df = pd.read_csv(food_data, index_col=0)

# %%
covid_df.head()
# Out:
#             iso_code continent       date  total_cases  new_cases  \
# location
# Afghanistan      AFG      Asia  2/24/2020          5.0        5.0
# Afghanistan      AFG      Asia  2/25/2020          5.0        0.0
# Afghanistan      AFG      Asia  2/26/2020          5.0        0.0
# Afghanistan      AFG      Asia  2/27/2020          5.0        0.0
# Afghanistan      AFG      Asia  2/28/2020          5.0        0.0
#
#              new_cases_smoothed  total_deaths  new_deaths  \
# location
# Afghanistan                 NaN           NaN         NaN
# Afghanistan                 NaN           NaN         NaN
# Afghanistan                 NaN           NaN         NaN
# Afghanistan                 NaN           NaN         NaN
# Afghanistan                 NaN           NaN         NaN
#
#              new_deaths_smoothed  total_cases_per_million  ...  \
# location                                                   ...
# Afghanistan                  NaN                    0.126  ...
# ...

# %%
food_df.head()
# Out:
#                      Alcoholic Beverages  Animal fats  Animal Products  \
# Country
# Afghanistan                       0.0014       0.1973           9.4341
# Albania                           1.6719       0.1357          18.7684
# Algeria                           0.2711       0.0282           9.6334
# Angola                            5.8087       0.0560           4.9278
# Antigua and Barbuda               3.5764       0.0087          16.6613
#
#                      Aquatic Products, Other  Cereals - Excluding Beer  \
# Country
# Afghanistan                              0.0                   24.8097
# Albania                                  0.0                    5.7817
# Algeria                                  0.0                   13.6816
# Angola                                   0.0                    9.1085
# Antigua and Barbuda                      0.0                    5.9960
#
#                        Eggs  Fish, Seafood  Fruits - Excluding Wine    Meat  \
# Country
# ...

# %%
covid_df['date'] = pd.to_datetime(covid_df['date'])
covid_df.head()
# Out:
#             iso_code continent       date  total_cases  new_cases  \
# location
# Afghanistan      AFG      Asia 2020-02-24          5.0        5.0
# Afghanistan      AFG      Asia 2020-02-25          5.0        0.0
# Afghanistan      AFG      Asia 2020-02-26          5.0        0.0
# Afghanistan      AFG      Asia 2020-02-27          5.0        0.0
# Afghanistan      AFG      Asia 2020-02-28          5.0        0.0
#
#              new_cases_smoothed  total_deaths  new_deaths  \
# location
# Afghanistan                 NaN           NaN         NaN
# Afghanistan                 NaN           NaN         NaN
# Afghanistan                 NaN           NaN         NaN
# Afghanistan                 NaN           NaN         NaN
# Afghanistan                 NaN           NaN         NaN
#
#              new_deaths_smoothed  total_cases_per_million  ...  \
# location                                                   ...
# Afghanistan                  NaN                    0.126  ...
# ...

# %%
# RENAME 'LOCATION' COLUMN IN COVID_DF AS 'COUNTRY'
covid_df.index.rename('Country', inplace = True)
covid_df
# Out:
#             iso_code continent       date  total_cases  new_cases  \
# Country
# Afghanistan      AFG      Asia 2020-02-24          5.0        5.0
# Afghanistan      AFG      Asia 2020-02-25          5.0        0.0
# Afghanistan      AFG      Asia 2020-02-26          5.0        0.0
# Afghanistan      AFG      Asia 2020-02-27          5.0        0.0
# Afghanistan      AFG      Asia 2020-02-28          5.0        0.0
# ...              ...       ...        ...          ...        ...
# Zimbabwe         ZWE    Africa 2021-12-27     205449.0     1098.0
# Zimbabwe         ZWE    Africa 2021-12-28     207548.0     2099.0
# Zimbabwe         ZWE    Africa 2021-12-29     207548.0        0.0
# Zimbabwe         ZWE    Africa 2021-12-30     211728.0     4180.0
# Zimbabwe         ZWE    Africa 2021-12-31     213258.0     1530.0
#
#              new_cases_smoothed  total_deaths  new_deaths  \
# Country
# Afghanistan                 NaN           NaN         NaN
# ...

# %%
covid_df.drop(["iso_code","new_cases_smoothed","new_deaths_smoothed","new_cases_per_million","new_cases_smoothed_per_million","new_deaths_per_million","new_deaths_smoothed_per_million","reproduction_rate","icu_patients","icu_patients_per_million","hosp_patients","hosp_patients_per_million","weekly_icu_admissions","weekly_icu_admissions_per_million","weekly_hosp_admissions","weekly_hosp_admissions_per_million","new_tests","new_tests_per_thousand","new_tests_smoothed","new_tests_smoothed_per_thousand","tests_units","new_vaccinations","new_vaccinations_smoothed","total_vaccinations_per_hundred","people_vaccinated_per_hundred","people_fully_vaccinated_per_hundred","total_boosters_per_hundred","new_vaccinations_smoothed_per_million","new_people_vaccinated_smoothed","new_people_vaccinated_smoothed_per_hundred","stringency_index","hospital_beds_per_thousand","human_development_index","excess_mortality_cumulative_absolute","excess_mortality_cumulative","excess_mortality","excess_mortality_cumulative_per_million","handwashing_facilities", "extreme_poverty", "female_smokers", "male_smokers", "total_cases_per_million", "total_deaths_per_million", "total_tests_per_thousand"], axis=1, inplace=True)
covid_df
# Out:
#             continent       date  total_cases  new_cases  total_deaths  \
# Country
# Afghanistan      Asia 2020-02-24          5.0        5.0           NaN
# Afghanistan      Asia 2020-02-25          5.0        0.0           NaN
# Afghanistan      Asia 2020-02-26          5.0        0.0           NaN
# Afghanistan      Asia 2020-02-27          5.0        0.0           NaN
# Afghanistan      Asia 2020-02-28          5.0        0.0           NaN
# ...               ...        ...          ...        ...           ...
# Zimbabwe       Africa 2021-12-27     205449.0     1098.0        4908.0
# Zimbabwe       Africa 2021-12-28     207548.0     2099.0        4940.0
# Zimbabwe       Africa 2021-12-29     207548.0        0.0        4940.0
# Zimbabwe       Africa 2021-12-30     211728.0     4180.0        4997.0
# Zimbabwe       Africa 2021-12-31     213258.0     1530.0        5004.0
#
#              new_deaths  total_tests  positive_rate  tests_per_case  \
# Country
# ...

# %%
# filter covid df on most recent date (12/31/21)
filtered_covid_df = covid_df[(covid_df['date'] >= '2021-01-01')]
filtered_covid_df.head()
# Out:
#             continent       date  total_cases  new_cases  total_deaths  \
# Country
# Afghanistan      Asia 2021-01-01      52513.0      183.0        2201.0
# Afghanistan      Asia 2021-01-02      52586.0       73.0        2211.0
# Afghanistan      Asia 2021-01-03      52709.0      123.0        2221.0
# Afghanistan      Asia 2021-01-04      52909.0      200.0        2230.0
# Afghanistan      Asia 2021-01-05      53011.0      102.0        2237.0
#
#              new_deaths  total_tests  positive_rate  tests_per_case  \
# Country
# Afghanistan        12.0          NaN            NaN             NaN
# Afghanistan        10.0          NaN            NaN             NaN
# Afghanistan        10.0          NaN            NaN             NaN
# Afghanistan         9.0          NaN            NaN             NaN
# Afghanistan         7.0          NaN            NaN             NaN
#
#              total_vaccinations  ...  total_boosters  population  \
# Country                          ...
# ...

# %%
# drop NA rows from covid df
# subset=['total_cases']
final_covid_df = filtered_covid_df.dropna(subset=['total_cases', 'total_deaths'])
final_covid_df.head(20)
# Out:
#             continent       date  total_cases  new_cases  total_deaths  \
# Country
# Afghanistan      Asia 2021-01-01      52513.0      183.0        2201.0
# Afghanistan      Asia 2021-01-02      52586.0       73.0        2211.0
# Afghanistan      Asia 2021-01-03      52709.0      123.0        2221.0
# Afghanistan      Asia 2021-01-04      52909.0      200.0        2230.0
# Afghanistan      Asia 2021-01-05      53011.0      102.0        2237.0
# Afghanistan      Asia 2021-01-06      53105.0       94.0        2244.0
# Afghanistan      Asia 2021-01-07      53207.0      102.0        2253.0
# Afghanistan      Asia 2021-01-08      53332.0      125.0        2257.0
# Afghanistan      Asia 2021-01-09      53400.0       68.0        2264.0
# Afghanistan      Asia 2021-01-10      53489.0       89.0        2277.0
# Afghanistan      Asia 2021-01-11      53538.0       49.0        2288.0
# Afghanistan      Asia 2021-01-12      53584.0       46.0        2301.0
# ...

# %%
final_covid_df.replace(np.nan, 0)
final_covid_df.head(20)
# Out:
#             continent       date  total_cases  new_cases  total_deaths  \
# Country
# Afghanistan      Asia 2021-01-01      52513.0      183.0        2201.0
# Afghanistan      Asia 2021-01-02      52586.0       73.0        2211.0
# Afghanistan      Asia 2021-01-03      52709.0      123.0        2221.0
# Afghanistan      Asia 2021-01-04      52909.0      200.0        2230.0
# Afghanistan      Asia 2021-01-05      53011.0      102.0        2237.0
# Afghanistan      Asia 2021-01-06      53105.0       94.0        2244.0
# Afghanistan      Asia 2021-01-07      53207.0      102.0        2253.0
# Afghanistan      Asia 2021-01-08      53332.0      125.0        2257.0
# Afghanistan      Asia 2021-01-09      53400.0       68.0        2264.0
# Afghanistan      Asia 2021-01-10      53489.0       89.0        2277.0
# Afghanistan      Asia 2021-01-11      53538.0       49.0        2288.0
# Afghanistan      Asia 2021-01-12      53584.0       46.0        2301.0
# ...

# %%
food_df.drop(["Animal fats","Aquatic Products, Other","Miscellaneous","Offals","Oilcrops","Pulses","Spices","Starchy Roots","Stimulants","Sugar Crops","Confirmed","Deaths","Recovered","Active","Population","Unit (all except Population)"], axis=1, inplace=True)
food_df

# %%
# drop NA rows from food df
final_food_df = food_df.dropna()
final_food_df.head(20)

# %%
final_covid_df.to_csv("cleaned_covid_19_data.csv")
# final_food_df.to_csv("cleaned_food_data.csv")
